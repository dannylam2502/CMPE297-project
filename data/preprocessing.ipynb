# %%
import pandas as pd

df = pd.read_csv(r"../docs/Seasons_Stats.csv", low_memory=False)
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (24691, 53)
#
# Columns:
# ['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
df.head(10)
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
# 5           5  1950.0       Ed Bartels    F  24.0  NYK   2.0 NaN NaN  NaN
# 6           6  1950.0      Ralph Beard    G  22.0  INO  60.0 NaN NaN  NaN
# 7           7  1950.0       Gene Berce  G-F  23.0  TRI   3.0 NaN NaN  NaN
# 8           8  1950.0    Charlie Black  F-C  28.0  TOT  65.0 NaN NaN  NaN
# 9           9  1950.0    Charlie Black  F-C  28.0  FTW  36.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# ...

# %%
df.describe(include='all').transpose().head(15)
# Out:
#               count unique            top  freq         mean          std  \
# Unnamed: 0  24691.0    NaN            NaN   NaN      12345.0  7127.822084
# Year        24624.0    NaN            NaN   NaN  1992.594989    17.429594
# Player        24624   3921  Eddie Johnson    33          NaN          NaN
# Pos           24624     23             PF  4966          NaN          NaN
# Age         24616.0    NaN            NaN   NaN    26.664405     3.841892
# Tm            24624     69            TOT  2123          NaN          NaN
# G           24624.0    NaN            NaN   NaN     50.83711    26.496161
# GS          18233.0    NaN            NaN   NaN    23.593375    28.632387
# MP          24138.0    NaN            NaN   NaN  1209.720317   941.146575
# PER         24101.0    NaN            NaN   NaN    12.479071     6.039014
# TS%         24538.0    NaN            NaN   NaN     0.493001     0.094469
# 3PAr        18839.0    NaN            NaN   NaN     0.158604     0.187495
# ...

# %%
pwd
# Out:
# 'c:\\Users\\asabry\\Desktop\\NLP-Project\\CMPE297-project\\data'
